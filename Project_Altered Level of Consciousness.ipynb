# %% [markdown]
# # ALTERED LEVEL OF CONSCIOUSNESS

# %% [markdown]
# # Read data from database and build a line chart

# %%
import numpy as np
import matplotlib.pyplot as plt
import MySQLdb
import pandas as pd
import itertools
import statsmodels.api as sm
from datetime import datetime
from calendar import monthrange
import math
import warnings
warnings.filterwarnings("ignore")

def getData(county):
    county = county
    conn = MySQLdb.connect(host="localhost", user="i501fa18_group7", passwd="rEm9z3dRGW11", db="i501fa18_group7")
    cursor = conn.cursor()
    if(county == 'all'):
        condition = 'SIT_PROVIDER_PRIM_IMPRESSION = \'Altered Level of Consciousness\''
    else:
        condition = 'inc_county = \'%s\' and SIT_PROVIDER_PRIM_IMPRESSION = \'Altered Level of Consciousness\'' % (county)
        
    str1="select LAST_DAY(INC_INCIDENTDATE) as INCIDENT_MTH , count(INC_INCIDENTID) as Numn_of_altc_calls from i501fa18_group7.emergency_medical_service_runs_2014 Where %s group by LAST_DAY(INC_INCIDENTDATE)"
    str2="union select LAST_DAY(INC_INCIDENTDATE) as INCIDENT_MTH , count(INC_INCIDENTID) as Numn_of_altc_calls from i501fa18_group7.emergency_medical_service_runs_2015 Where %s group by LAST_DAY(INC_INCIDENTDATE)"
    str3="union select LAST_DAY(INC_INCIDENTDATE) as INCIDENT_MTH , count(INC_INCIDENTID) as Numn_of_altc_calls from i501fa18_group7.emergency_medical_service_runs_2016 Where %s group by LAST_DAY(INC_INCIDENTDATE)"
    str4="union select LAST_DAY(INC_INCIDENTDATE) as INCIDENT_MTH, count(INC_INCIDENTID) as Numn_of_altc_calls from i501fa18_group7.emergency_medical_service_runs_2017 Where  %s and LAST_DAY(INC_INCIDENTDATE) < \'2017-08-31\' group by LAST_DAY(INC_INCIDENTDATE)"


    query = str1%(condition) + str2%(condition)+ str3%(condition)+ str4%(condition)
    cursor.execute(query);
    rows = cursor.fetchall() 
    months = []
    altc_calls = []
    for i in rows:
        months.append(datetime.combine(i[0],datetime.min.time()))
        altc_calls.append(i[1])
    my_data = pd.DataFrame(
           {'Months': months,
            'Altered_Consc_Calls': altc_calls
            })

    my_data = my_data.set_index('Months')
    return my_data;

def decomposeData(my_data):
    check_seasonal = sm.tsa.seasonal_decompose(my_data, model='multiplicative')
    fig = check_seasonal.plot()
    plt.title('Seasonal trending of the Altered Level of Consciousness Calls Data')
    plt.show()
alt_conc_calls = getData('all');
print("Properties of the data are :" , alt_conc_calls.describe())
alt_conc_calls.plot(figsize=(15,6))
plt.title('Altered Level of Consciousness Calls by Month')
plt.show()
# Out:
# Properties of the data are :        Altered_Consc_Calls
# count            43.000000
# mean           1884.744186
# std             365.148834
# min            1020.000000
# 25%            1628.500000
# 50%            1974.000000
# 75%            2140.500000
# max            2405.000000

# %% [markdown]
# # Seasonal decompose of the data

# %%
decomposeData(alt_conc_calls)

# %% [markdown]
# # Train the ARIMAX model for data from 2014 to 2016

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

min_aic = 1000
min_param = ()
min_param_seasonal = ()

train_data = alt_conc_calls[:2016]

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            train_mod = sm.tsa.statespace.SARIMAX(train_data,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = train_mod.fit()
            if (results.aic <= min_aic):
                min_aic = results.aic
                min_param = param
                min_param_seasonal = param_seasonal
            
            #print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue

print('minimum AIC in observed at ', min_param, min_param_seasonal, min_aic)
# Out:
# minimum AIC in observed at  (1, 1, 0) (1, 1, 0, 12) 209.64640069282908

# %% [markdown]
# # Build ARIMAX model using the parameters for minimum AIC

# %%
mod = sm.tsa.statespace.SARIMAX(alt_conc_calls, 
                                order= min_param,
                                seasonal_order= min_param_seasonal,
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

for i in range(3):
    print(results.summary().tables[i])
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                Altered_Consc_Calls   No. Observations:                   43
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -101.823
# Date:                            Sat, 15 Dec 2018   AIC                            209.646
# Time:                                    20:04:33   BIC                            212.146
# Sample:                                01-31-2014   HQIC                           209.895
#                                      - 07-31-2017
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5267      0.306     -1.722      0.085      -1.126       0.073
# ar.S.L12      -0.5624      0.256     -2.201      0.028      -1.063      -0.061
# ...

# %% [markdown]
# # Check diagnostics to make sure the model doesn't produce incorrect results

# %%
results.plot_diagnostics(figsize=(16,8))
plt.show()

# %% [markdown]
# # Predicting the values for 2017 based on training data

# %%
def forecastALTCONC(in_data):
    mod = sm.tsa.statespace.SARIMAX(alt_conc_calls, 
                                order= min_param,
                                seasonal_order= min_param_seasonal,
                                enforce_stationarity=False,
                                enforce_invertibility=False)

    results = mod.fit()

    for i in range(3):
         print(results.summary().tables[i])
            
    results.plot_diagnostics(figsize=(16,8))
    plt.show()

    pred = results.get_prediction(start=pd.to_datetime('2017-01-31'), dynamic=False)
    pred_ci = pred.conf_int() 
    ax = in_data['2014':].plot(label='observed')
    pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9, figsize=(15, 8))
    print(pred_ci)
    ax.fill_between(pred_ci.index,
                 pred_ci.iloc[:, 0],
                 pred_ci.iloc[:, 1], color='k', alpha=.3)
    ax.set_xlabel('Months')
    ax.set_ylabel('Altered Level of Consciousness Calls')
    plt.legend()
    plt.title('Actual v/s Altered Level of Consciousness Calls')
    plt.show()
    
forecastALTCONC(alt_conc_calls)
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                Altered_Consc_Calls   No. Observations:                   43
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -101.823
# Date:                            Sat, 15 Dec 2018   AIC                            209.646
# Time:                                    20:04:38   BIC                            212.146
# Sample:                                01-31-2014   HQIC                           209.895
#                                      - 07-31-2017
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5267      0.306     -1.722      0.085      -1.126       0.073
# ar.S.L12      -0.5624      0.256     -2.201      0.028      -1.063      -0.061
# ...
